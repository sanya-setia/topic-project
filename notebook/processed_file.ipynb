# %% [markdown]
# # Topic project 4.1 Applying NLP for topic modelling in a real-life context
#
# **Welcome to your topic project: Applying NLP for topic modelling in a real-life context**
#
# In this project, you will bridge the gap between theory and practical application by developing automated topic modelling tools tailored to a specific industry context.
#
#
# Applying NLP for topic modelling is crucial for data analysis in business because it enables companies to identify and understand key themes and patterns within large volumes of text data. This efficiency allows businesses to extract essential insights and trends without manually sifting through extensive documents. Automated topic modelling helps businesses make informed decisions faster, which helps to improve productivity and gain a competitive edge. Additionally, it supports better information management by uncovering underlying topics in reports, emails, customer feedback, and market research, which enhances overall business intelligence and strategic planning.
#
#
#
#
# Please set aside approximately **19 hours** to complete the topic project by **Thursday, 22 August at 5 p.m. (UK Time)**.
#
# <br>
#
# ## **Business context**
#
# The PureGym Group, founded in 2008, has approximately 2 million members and 600 gyms across the world (particularly in the UK, Denmark, and Switzerland). As one of the world’s largest value fitness operators, PureGym appeals to a broad range of customers by offering high-quality, low-cost, and flexible fitness facilities. The company’s customer-centric proposition – affordable membership fees, no fixed-term contracts, and 24/7 access to high-quality gyms – differentiates it from more traditional gyms and elevates it as a market leader within this space.
#
# This focus on the customer is centred on wanting to understand what motivates members to join and what factors influence their behaviours once they have joined. Understanding how to leverage innovative technology to influence, improve, and simplify their experience allows PureGym to foster an open, welcoming, and diverse environment for its members while maintaining the value proposition that PureGym is built upon.
#
# With the shift in focus to value-for-money memberships across the gym industry, PureGym seeks to achieve its mission of ‘inspiring a healthier world by providing members with affordable access to the benefits being healthy can offer’.
#
#
# <br></br>
#
# ## **Objective**
#
# By the end of this topic project, you will have analysed PureGym's review data to uncover key drivers that provide actionable insights for enhancing customer experience.
#
# In the Notebook, you will:
#
# - Use two data sets containing customer reviews from Google and Trustpilot.
# - Perform basic level analysis by finding the frequently used words in both data sets.
# - Generate a wordcloud to visualise the most frequently used words in the reviews.
# - Apply BERTopic for topic modelling, keeping track of gym locations, to identify common topics and words in the negative reviews.
# - Identify the locations that have the most negative reviews.
# - Use the built-in visualisation functions in BERTopic to cluster and visually represent the topics and words in these reviews, thereby helping to identify specific themes from the reviews.
# - Conduct a comparison with Gensim’s LDA model to validate the topic modelling results.
# - Perform emotion analysis to identify the emotions associated with customer reviews.
# - Filter out angry reviews and apply BERTopic to discover prevalent topics and words being discussed these negative reviews.
# - Leverage the multi-purpose capability of the state-of-the-art Falcon-7b-instruct model, with the help of prompts, to identify top topics in each review.
# - Use a different prompt with the Falcon-7b-instruct model to further generate suggestions for improvements for PureGym, based on the top topics identified from the negative reviews.
#
#
# You will also write a report summarising the results of your findings and recommendations.
#
#
# <br></br>
#
# ## **Assessment criteria**
# By completing this project, you will be able to provide evidence that you can:
#
# - Investigate real-world data to find potential trends for deeper investigation.
# -Preprocess and refine textual data for visualisations.
# -Apply topic modelling using various techniques.
# -Apply emotion analysis using BERT.
# -Evaluate the outcomes of your investigation.
# -Communicate actionable insights.
#
#
#
# <br></br>
#
# ## **Project guidance**
#
# **Import packages and data:**
# 1. 1. Import the data set with the provided URL:
#   - Data set's Drive link: https://drive.google.com/drive/folders/1azch13dtGeAkbnEjqeoyl3nU9jheojU4
# 2. Import the data file **Google_12_months.xlsx** into a dataframe.
# 3. Import the data file **Trustpilot_12_months.xslx** into a dataframe.
# 4. Remove any rows with missing values in the Comment column (Google review) and Review Content column (Trustpilot).
#
#
# **Conducting initial data investigation:**
#
# 1. - Find the number of unique locations in the Google data set.
#
#   - Find the number of unique locations in the Trustpilot data set.
#
#   - Use Club's Name for the Google data set.
#
#   - Use Location Name for the Trustpilot data set.
# 2. Find the number of common locations between the Google data set and the Trustpilot data set.
# 3. Perform preprocessing of the data – change to lower case, remove stopwords using NLTK, and remove numbers.
# 4. Tokenise the data using word_tokenize from NLTK.
# 5. Find the frequency distribution of the words from each data set's reviews separately. You can use nltk.freqDist.
# 6. Plot a histogram/bar plot showing the top 10 words from each data set.
# 7. Use the wordcloud library on the cleaned data and plot the word cloud.
# 8. Create a new dataframe by filtering out the data to extract only the negative reviews from both data sets.
#
#   • For Google reviews, overall scores < 3 can be considered negative scores.
#
#   • For Trustpilot reviews, stars < 3 can be considered negative scores.
#
#   Repeat the frequency distribution and wordcloud steps on the filtered data consisting of only negative reviews.
#
#
# **Conducting initial topic modelling:**
#
# 1. With the data frame created in the previous step:
#
#   • Filter out the reviews that are from the locations common to both data sets.
#
#   • Merge the reviews to form a new list.
#
# 2. Preprocess this data set. Use BERTopic on this cleaned data set.
# 3. Output: List out the top topics along with their document frequencies.
# 4. For the top 2 topics, list out the top words.
# 5. Show an interactive visualisation of the topics to identify the cluster of topics and to understand the intertopic distance map.
# 6. Show a barchart of the topics, displaying the top 5 words in each topic.
# 7. Plot a heatmap, showcasing the similarity matrix.
# 8. For 10 clusters, provide a brief description in the Notebook of the topics they comprise of along with the general theme of the cluster, evidenced by the top words within each cluster's topics.
#
# **Performing further data investigation:**
#
# 1. List out the top 20 locations with the highest number of negative reviews. Do this separately for Google and Trustpilot's reviews, and comment on the result. Are the locations roughly similar in both data sets?
# 2. Merge the 2 data sets using Location Name and Club's Name.
#
#   Now, list out the following:
#
#   • Locations
#
#   • Number of Trustpilot reviews for this location
#
#   • Number of Google reviews for this location
#
#   • Total number of reviews for this location (sum of Google reviews and Trustpilot reviews)
#
#   Sort based on the total number of reviews.
# 3. For the top 30 locations, redo the word frequency and word cloud. Comment on the results, and highlight if the results are different from the first run.
# 4. For the top 30 locations, combine the reviews from Google and Trustpilot and run them through BERTopic.
#
#   Comment on the following:
#
#   • Are the results any different from the first run of BERTopic?
#
#   • If so, what has changed?
#
#   • Are there any additional insights compared to the first run?
#
# **Conducting emotion analysis:**
#
# 1. Import the BERT model bhadresh-savani/bert-base-uncased-emotion from Hugging Face, and set up a pipeline for text classification.
# 2. With the help of an example sentence, run the model and display the different emotion classifications that the model outputs.
# 3. Run this model on both data sets, and capture the top emotion for each review.
# 4. Use a bar plot to show the top emotion distribution for all negative reviews in both data sets.
# 5. Extract all the negative reviews (from both data sets) where anger is top emotion.
# 6. Run BERTopic on the output of the previous step.
# 7. Visualise the clusters from this run. Comment on whether it is any different from the previous runs, and whether it is possible to narrow down the primary issues that have led to an angry review.
#
# **Using a large language model from Hugging Face:**
#
# 1. Load the following model: tiiuae/falcon-7b-instruct. Set the pipeline for text generation and a max length of 1,000 for each review.
# 2. Add the following prompt to every review, before passing it on to the model: **In the following customer review, pick out the main 3 topics. Return them in a numbered list format, with each one on a new line.**
#
#   Run the model.
#
#   Note: If the execution time is too high, you can use a subset of the bad reviews (instead of the full set) to run this model.
# 3. The output of the model will be the top 3 topics from each review. Append each of these topics from each review to create a comprehensive list.
# 4. Use this list as input to run BERTopic again.
# 5. Comment about the output of BERTopic. Highlight any changes, improvements, and if any further insights have been obtained.
# 6. Use the comprehensive list from Step 3.
#
#   Pass it to the model as the input, but pre-fix the following to the prompt: **For the following text topics obtained from negative customer reviews, can you give some actionable insights that would help this gym company?**
#
#   Run the Falcon-7b-Instruct model.
# 7. List the output, ideally in the form of suggestions, that the company can employ to address customer concerns.
#
# **Using Gensim:**
# 1. Perform the preprocessing required to run the LDA model from Gensim. Use the list of negative reviews (combined Google and Trustpilot reviews).
# 2. Using Gensim, perform LDA on the tokenised data. Specify the number of topics = 10.
# 3. Show the visualisations of the topics, displaying the distance maps and the bar chart listing out the most salient terms.
# 4. Comment on the output and whether it is similar to other techniques, or whether any extra insights were obtained.
#
# **Report:**
# 1. Document your approach and major inferences from the data analysis.
# 2. When you have completed the project:
#   - Download your completed Notebook as an IPYNB (Jupyter Notebook) or PY (Python) file. Save the file as follows: **LastName_FirstName_CAM_C301_Week_4and5_Topic_project.ipynb**.
#   - Prepare a detailed report (between 800–1,000 words) that includes:
#     - an overview of your approach
#     - a description of your analysis
#     - an explanation of the insights you identified
#     - a summary of the comments requested in earlier steps
#     - final insights, based on the output obtained from the various models employed
#   - Save the document as a PDF named according to the following convention: **LastName_FirstName_CAM_C301_Week_4and5_Topic_project.pdf**.
#   - Submit your Notebook and PDF document by **Thursday, 22 August at 5 p.m. (UK Time)**.
#
#
# <br></br>
# > **Declaration**
# >
# > By submitting your project, you indicate that the work is your own and has been created with academic integrity. Refer to the Cambridge plagiarism regulations.

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /home/sanyasetia/topic-project/.venv/lib/python3.12/site-packages (3.9.1)
# Requirement already satisfied: click in /home/sanyasetia/topic-project/.venv/lib/python3.12/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /home/sanyasetia/topic-project/.venv/lib/python3.12/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/sanyasetia/topic-project/.venv/lib/python3.12/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /home/sanyasetia/topic-project/.venv/lib/python3.12/site-packages (from nltk) (4.67.1)

# %%
# !pip install svgling
# Out:
# Requirement already satisfied: svgling in /home/sanyasetia/topic-project/.venv/lib/python3.12/site-packages (0.5.0)
# Requirement already satisfied: svgwrite in /home/sanyasetia/topic-project/.venv/lib/python3.12/site-packages (from svgling) (1.4.3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize,RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
from nltk.stem.porter import PorterStemmer
import gdown
import os
import re

# %%
from joblib import dump, load
import os

# %%
def save_joblib(obj, filepath):
    """Save object using joblib"""
    try:
        dump(obj,filepath)
        print(f"Save to {filepath}")
    except Exception as e:
        print(f"Error saving joblib file: {e}")
        
def load_joblib(filepath):
    """Load object using joblib"""
    try:
        return load(filepath)
    except Exception as e:
        print(f"Error loading joblib file: {e}")
        return None

# %%
folder_id = '1azch13dtGeAkbnEjqeoyl3nU9jheojU4'

output_folder = "dataset_files"

os.makedirs(output_folder, exist_ok =True)

gdown.download_folder(id = folder_id, output = output_folder, quiet=False)

print("Download Complete.")
# Out:
# Retrieving folder contents
# Processing file 13TeZTT6oqk3iPELBhFx9hComIfChKw4m Google_12_months.xlsx
# Processing file 1V6Pr6xWrHSHaothB61MJbR7mPFHwQ1u6 Trustpilot_12_months.xlsx
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=13TeZTT6oqk3iPELBhFx9hComIfChKw4m
# To: /home/sanyasetia/topic-project/notebook/dataset_files/Google_12_months.xlsx
# 100%|██████████| 2.08M/2.08M [00:00<00:00, 5.27MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1V6Pr6xWrHSHaothB61MJbR7mPFHwQ1u6
# To: /home/sanyasetia/topic-project/notebook/dataset_files/Trustpilot_12_months.xlsx
# 100%|██████████| 2.83M/2.83M [00:00<00:00, 5.45MB/s]
# Download Complete.
# Download completed

# %%
files = [f for f in os.listdir(output_folder) if f.endswith('.xlsx')]

df_google = pd.read_excel(os.path.join(output_folder, files[0]),engine='openpyxl') #compatibility with modern excels
df_trust = pd.read_excel(os.path.join(output_folder, files[1]),engine='openpyxl')

print("First file:\n", df_google.head())
print("Second file:\n",df_trust.head())
# Out:
# First file:
#    Customer Name SurveyID for external use (e.g. tech support)  \
# 0            **                      ekkt2vyxtkwrrrfyzc5hz6rk
# 1            **                      e9b62vyxtkwrrrfyzc5hz6rk
# 2            **                      e2dkxvyxtkwrrrfyzc5hz6rk
# 3            **                      e3tfxvyxtkwrrrfyzc5hz6rk
# 4            **                      edkrxvyxtkwrrrfyzc5hz6rk
#
#                          Club's Name Social Media Source       Creation Date  \
# 0            Leeds City Centre North      Google Reviews 2024-05-09 23:49:18
# 1             Cambridge Leisure Park      Google Reviews 2024-05-09 22:48:39
# 2                     London Holborn      Google Reviews 2024-05-09 22:08:14
# 3  Cheshunt Brookfield Shopping Park      Google Reviews 2024-05-09 21:58:07
# 4                 Bristol Union Gate      Google Reviews 2024-05-09 21:48:00
#
#                                              Comment  Overall Score
# 0                                                NaN              4
# 1  Too many students from two local colleges go h...              1
# 2  Best range of equipment, cheaper than regular ...              5
# 3  Good gym when it’s not busy, tend to get too b...              4
# 4  (current member)\n\nGym is quite dirty, more o...              1
# Second file:
#                    Review ID Review Created (UTC)   Review Consumer User ID  \
# 0  663d40378de0a14c26c2f63c  2024-05-09 23:29:00  663d4036d5fa24c223106005
# 1  663d3c101ccfcc36fb28eb8c  2024-05-09 23:11:00  5f5e3434d53200fa6ac57238
# 2  663d375859621080d08e6198  2024-05-09 22:51:00  57171ba90000ff000a18f905
# 3  663d4fa1f25670a3339ccf6d  2024-05-09 22:35:00  663d4fa0d5fa24251d1068e7
# 4  663d3251d8367b7b3c4ace64  2024-05-09 22:30:00  60c20598384d84001a4250de
#
#                     Review Title  \
# 0        A very good environment
# 1  I love to be part of this gym
# 2                 Extremely busy
# 3                    Great vibes
# 4      Everything it needs to be
#
#                                       Review Content  Review Stars  \
# 0                            A very good environment             5
# 1  I love to be part of this gym. Superb value fo...             5
# 2                      Extremely busy, no fresh air.             1
# 3                         Great vibes, fantastic gym             5
# 4             Clean, well managed, classes are good.             5
#
#   Source Of Review Review Language              Domain URL Webshop Name  \
# 0            AFSv2              en  http://www.puregym.com   PureGym UK
# 1            AFSv2              en  http://www.puregym.com   PureGym UK
# 2            AFSv2              en  http://www.puregym.com   PureGym UK
# 3            AFSv2              en  http://www.puregym.com   PureGym UK
# 4            AFSv2              en  http://www.puregym.com   PureGym UK
#
#            Business Unit ID  Tags Company Reply Date (UTC)  \
# 0  508df4ea00006400051dd7b1   NaN      2024-05-10 08:12:00
# 1  508df4ea00006400051dd7b1   NaN      2024-05-10 08:13:00
# 2  508df4ea00006400051dd7b1   NaN                      NaT
# 3  508df4ea00006400051dd7b1   NaN                      NaT
# 4  508df4ea00006400051dd7b1   NaN      2024-05-10 08:14:00
#
#                 Location Name                           Location ID
# 0  Solihull Sears Retail Park  7b03ccad-4a9d-4a33-9377-ea5bba442dfc
# 1                   Aylesbury  612d3f7e-18f9-492b-a36f-4a7b86fa5647
# 2         Sutton Times Square  0b78c808-f671-482b-8687-83468b7b5bc1
# 3             London Finchley  bc3a9a8c-defe-47b3-8ee6-f73a03b7447e
# 4                    Crayford  9ce470b7-57df-4533-af2f-c539422fed14

# %% [markdown]
# ## Removing rows with information missing in the Comment section

# %%
print(df_google['Comment'].isnull().sum(),df_trust['Review Content'].isnull().sum())
# Out:
# 9352 0

# %% [markdown]
# ## Dropping Rows where the Comment/Review Content Columns are empty

# %%
df_google.dropna(subset=['Comment'], inplace=True)
df_trust.dropna(subset=['Review Content'],inplace=True)

print(df_google['Comment'].isnull().sum(),df_trust['Review Content'].isnull().sum())
# Out:
# 0 0

# %%
google_text = pd.DataFrame(df_google['Comment'])
trust_text = pd.DataFrame(df_trust['Review Content'])

# %% [markdown]
# # Conducting initial data investigation

# %%
unique_locations_google = df_google['Club\'s Name'].unique()

unique_locations_trust = df_trust['Location Name'].unique()

print("Unique Google Locations\n",unique_locations_google, "Unique Trust Pilot Locations\n", unique_locations_trust)
# Out:
# Unique Google Locations
#  ['Cambridge Leisure Park' 'London Holborn'
#  'Cheshunt Brookfield Shopping Park' 'Bristol Union Gate'
#  '209 - Slagelse, Jernbanegade' 'New Barnet'
#  '155 - Odense C., Grønløkkevej' 'Glasgow Robroyston' 'Sunderland'
#  '115 - Dannebrogsgade, Aalborg' 'Hatfield' 'Sheffield Millhouses'
#  'Manchester Cheetham Hill' 'London North Finchley'
#  'Milton Keynes Kingston Centre' 'Manchester Exchange Quay'
#  'Newcastle Eldon Garden' 'Airdrie' 'Staines' 'Cardiff Central'
#  'Bangor Wales' 'Northampton Central' 'West Bromwich' 'Motherwell'
#  'Stafford' 'Brugg' 'Lincoln Carlton Centre' 'Colchester Retail Park'
#  'London Oval' 'Lyss' 'Glasgow Clydebank' 'Cambridge Grafton Centre'
#  '114 - Valby, Mosedalvej' 'Merthyr Tydfil' 'Southampton Central'
#  'Norwich Castle Mall' 'Rochdale' 'Aylesbury' 'Liverpool Kirkby'
#  'Nottingham Beeston' 'London Enfield' 'Coleraine'
#  '279 - Sct. Jørgens Park, Næstved' 'Leicester St Georges Way' 'Epsom'
#  'Galashiels' 'Salford' 'Altrincham' 'Southampton Shirley'
#  'Broadstairs Westwood Gateway Retail Park' 'Loughborough'
#  'London Woolwich' 'Leeds Hunslet' 'Coventry Skydome' 'Wetzikon'
#  'Glasgow Bath Street' 'Brighton London Road' 'London Holloway Road'
#  'Redditch Ringway' 'Peterborough Brotherhood Retail Park'
#  'Haverhill Retail Park' 'St Albans' 'Norwich Aylsham Road' 'Byfleet'
#  'Manchester Market Street' '277 - Kolding, Bramdrupdam' 'Dumfries'
#  'Widnes' 'Reading Caversham Road' 'Solihull' 'London Greenwich'
#  'Shrewsbury Meole Brace' 'Sheffield Meadowhall' 'London Camden'
#  'Warrington Central' 'London Waterloo' 'Tunbridge Wells' 'Rushden'
#  'Uttoxeter' 'London Southgate' 'Aberdeen Shiprow' 'London Hoxton'
#  '144 - Odder, Banegårdsgade' 'Walsall Crown Wharf' 'Horgen'
#  'london Croydon' 'Liverpool Edge Lane' 'Eastbourne' 'London Edgware'
#  '186 - Stenløse, Rådhustorvet' 'Manchester Eccles' 'Bristol Brislington'
#  'London Acton' 'Ashford' 'London Farringdon' 'London Streatham'
#  'London Angel' 'Bury' 'Chester' 'Knaresborough' 'Burnham' 'Didcot'
#  'London Kingston' 'Birmingham Snow Hill' 'London Marylebone'
#  'Northallerton' 'Glasgow Giffnock' 'London Charlton'
#  'Manchester Stretford' 'Birmingham Longbridge' 'Leeds Thorpe Park'
#  'London Shoreditch High Street' 'Lichfield' 'Nottingham Basford'
#  'Walton-on-Thames' 'Harrogate' 'Basel Markthalle'
#  'Bournemouth the triangle' 'Bristol Harbourside' 'Adliswil'
#  'London Wembley' 'London Swiss Cottage' 'Springfield' 'Bletchley'
#  'Bradford Idle' 'Bracknell' "Belfast St Anne's Square"
#  'Lisburn Laganbank' 'Aberdeen Kittybrewster' 'Taunton' 'York'
#  'Maidenhead' 'Bristol Abbey Wood Retail Park' 'Canterbury Sturry Road'
#  'London Seven Sisters' 'Bedford Heights' 'London Park Royal'
#  'Leeds Regent Street' '256 - Kbh. N., Farumgade' 'Zürich Altstetten'
#  'Oldham' 'London Wandsworth' 'Blyth' '283 - Kbh. S., Asger Jorns Allé'
#  'London Stratford' 'Harlow' 'Burgess Hill' 'London Beckton'
#  'Edinburgh West' '602 - Kbh. S., Rued Langgaards Vej'
#  'London Kidbrooke Village' 'Selby' 'Hednesford Cannock'
#  'London Canary Wharf' 'Gateshead' 'London Bermondsey'
#  'Gloucester Retail Park' 'Manchester Urban Exchange' 'Maldon' 'Yate'
#  '281 - Albertslund, Roskildevej' 'Romford' 'Oftringen' 'London Finchley'
#  'Crewe Grand Junction Retail Park' 'Inverness Inshes' 'Yeovil Houndstone'
#  'Tysons Corner' 'Southend Fossetts Park' 'Leeds Bramley' 'Rayleigh'
#  'Basildon' '119 - Gentofte, Lyngbyvej' 'Newcastle Longbenton'
#  'Nottingham West Bridgford' '140 - Frb., Peter Bangs Vej'
#  'London Tottenham Court Road' 'St. Gallen City' 'Dagenham'
#  'Bristol Eastgate' 'London Leytonstone' 'Dietikon' 'Reading Calcot'
#  'Preston' 'Pfäffikon SZ' 'Stoke on Trent North' 'Bridgwater'
#  'London Monument' 'London Sydenham' 'Bern Bümpliz'
#  'Birmingham Beaufort Park' 'Wakefield' 'Bachenbülach' 'Leamington Spa'
#  'Chatham' 'Baar' 'Birmingham City Centre' 'Plymouth Marsh Mills'
#  'Stowmarket' 'Derby' 'Warrington North' 'Sutton Coldfield' 'Aarau'
#  'London Clapham' '133 - Korsør, Norvangen' 'Stoke on Trent East'
#  'London Lambeth' 'Portishead' 'Stratford-Upon-Avon'
#  'Manchester Bury New Road' 'Uster' 'Livingston'
#  'Bournemouth - Mallard Road' 'Liverpool Central' 'Saffron Walden'
#  'Chelmsford - The Meadows' 'London Colney' 'London Bayswater'
#  'Gloucester Quedgeley' 'London St Pauls' 'London Muswell Hill'
#  'Manchester Moston' 'London Camberwell New Road' 'Southampton Bitterne'
#  'Torquay' 'London Bromley' 'Birmingham West' 'Ipswich Buttermarket'
#  'Hemel Hempstead' 'Swindon Mannington Retail Park' 'Brierley Hill'
#  'Leicester Walnut Street' 'Telford' 'Wolverhampton South'
#  '234 - Esbjerg, Stormgade' '147 - Ballerup, Banegårdspladsen' 'Paisley'
#  'Woking' 'Great Yarmouth' '246 - Solrød Strand, Solrød Center'
#  'Manchester Spinningfields' 'London Aldgate' 'Tyldesley'
#  'Wolverhampton Bentley Bridge' 'London Piccadilly' 'London Catford'
#  'Wisbech' 'Corby' 'Derby Kingsway' 'South Ruislip' 'London Lewisham'
#  'Fribourg' 'Blackburn The Mall' 'Sheffield Crystal Peaks' 'Tamworth'
#  '218 - Rødovre, Rødovre Centrum' 'Lausanne Prilly'
#  '240 - Brabrand, Cityvest' 'Zürich West' 'Edinburgh Craigleith'
#  'Oxford Templars Shopping Park' 'Newport Gwent' 'Glasgow Shawlands'
#  'Aldershot - Westgate' 'Fareham' 'Leeds City Centre North'
#  'Banbury Cross' 'Basel Clara Huus' 'Northolt' 'Cirencester'
#  '603 - Hvidovre, Biblioteksvej' 'Plymouth Alexandra Road' 'Purley'
#  'London Great Portland Street' 'Manchester Debdale'
#  'Leeds City Centre South' '213 - Gentofte, Kildeskovshallen'
#  'London Hayes' 'West Thurrock' 'Sevenoaks' 'Manchester First Street'
#  'Folkestone' '276 - Kolding, Slotssøbadet' 'Dunfermline'
#  '191 - Kbh. S., Englandsvej' 'Lenzburg' 'Cardiff Western Avenue'
#  'London Kentish Town' 'Hitchin' 'Ashton Under Lyne'
#  'London Hammersmith Palais' 'Newbury' 'London Limehouse'
#  'Milton Keynes Winterhill' 'Glossop' 'La Chaux de Fonds'
#  'London Colindale' 'London Fulham' '608 - Kennedy, Aalborg'
#  'Norwich Riverside' 'Halifax' 'Stockport South' 'Maidstone - The Mall'
#  '223 - Kbh. NV., Tomsgårdsvej' 'Bath Spring Wharf'
#  '161 - Ringsted, Nørregade' 'London East Sheen' '164 - Frb., Forum'
#  'London Bank' 'Northwich' 'London Tower Hill' 'Rorschach'
#  '171 - Frederikssund, Falkenborggården' '212 - Hvidovre, Stationscenter'
#  '123 - Kbh. Ø., Århusgade' 'Colne' 'Leeds Kirkstall Bridge'
#  'London Crouch End' 'Peterborough Serpentine' 'Trowbridge'
#  'Cannock Orbital Retail Park' 'London - Twickenham'
#  '124 - Kbh. NV., Lygten' 'Bromsgrove Retail Park' 'Andover'
#  'Nottingham Colwick' 'Brighton Central' 'Evesham'
#  'Nottingham Castle Marina' 'Edinburgh Exchange Crescent'
#  'Bradford Thornbury' '107 - Odense C., Slotscenter'
#  'St Ives Cambridgeshire' '224 - Kokkedal, Egevangen'
#  'Portsmouth Commercial Road' 'Aberdeen Wellington' 'Bicester'
#  'Dudley Tipton' "288 - Haderslev, Christian X's Vej" 'Billericay'
#  '620 - Kbh. SV., Sjælør' 'Cardiff Bay' 'Hereford'
#  '263 - Farvervej, Viborg' 'Aberdeen Rubislaw' 'Dundee' 'Mansfield'
#  'Nuneaton' 'Elkridge' 'Watford Waterfields'
#  '199 - Silkeborg, Stagehøjvej' 'Birmingham Maypole' 'Aintree' 'Grimsby'
#  'Wohlen' '179 - Gilleleje, Fiskerbakken' 'Stockport North' 'Grantham'
#  'Heanor' 'Southport' 'London Finsbury Park' 'Salisbury' 'Linlithgow'
#  'London Bow Wharf' 'London Palmers Green' 'Poole' 'Bromborough' 'Wrexham'
#  '287 - Kbh. S., Lergravsvej' 'Edinburgh Quartermile' 'Ipswich Ravenswood'
#  'Edinburgh Fort Kinnaird' 'London Whitechapel' 'London Putney'
#  '207 - Kbh. S., Bryggen' '190 - Horsens, Ove Jensens Allé' 'Witney'
#  'Port Talbot' 'Portsmouth North Harbour' '614 - Viby J., Skanderborgvej'
#  '284 - Porsvej, Aalborg' 'Belfast Boucher Road'
#  '261 - Kbh. Ø., Oslo Plads' 'Durham Arnison' 'Runcorn'
#  '228 - Brøndby Strand Centrum' 'Northampton Weston Favell'
#  '108 - Kbh NV., Emdrup Station' '236 - Hvidovre, Frihedens Butikscenter'
#  'Denton' '113 - Århus N., JBV' '158 - Friis, Aalborg' 'Falkirk' 'Consett'
#  'St. Gallen West' 'Bath Victoria Park' '262 - Hobro' 'Boston'
#  '250 - Højbjerg, Rundhøj Torv' 'Glasgow Milngavie' 'Sutton Times Square'
#  '264 - Herning, Vestergade' 'Olten' 'Elgin' 'Barnstaple' 'London Borough'
#  '247 - Esbjerg, Randersvej' 'Worcester' 'Liverpool Brunswick'
#  '285 - Vejle, Damhaven' 'Belfast Adelaide Street' '153 - Viby'
#  '134 - Roskilde, Algade' '624 - Fredericia, Nørre Voldgade'
#  '227 - Odense M., Klokkestøbervej' 'London East India Dock'
#  '189 - Slagelse, Bornholmsvej' 'Weston Super Mare' 'Caerphilly'
#  '163 - Lyngby, Jernbanepladsen' 'London Orpington Central' 'Alloa'
#  '249 - Ikast, Strøget' '231 - Langagervej, Aalborg' 'Kirkcaldy'
#  '215 - Søborg, Søborg Hovedgade \xa0' 'Bangor Northern Ireland'
#  '255 - Kalundborg, Sct. Jørgensbjerg' 'Buckingham'
#  '258 - Vordingborg, Bryggervangen' 'Derry Londonderry'
#  'Coventry Bishop Street' '257 - Kolding, Vonsildvej' 'Macclesfield'
#  'Ormskirk' 'Cardiff Gate' 'Glasgow Hope Street' 'East Kilbride'
#  'Swindon Stratton' 'Camberley' 'Geneve le Bouchet'
#  '248 - Vanløse, Vanløse Torv' '604 - Kbh. V., Vesterbrogade'
#  '170 - Glostrup, Banegårdsvej' 'Exeter Fore Street'
#  '220 - Holbæk, Ahlgade' '609 - Odense C., Dannebrogsgade'
#  '106 - Frb., C. F. Richs Vej' '165 - Taastrup, Taastrup Torv'
#  '244 - Vallensbæk, Stationstorv' '259 - Vejle, Bredballe'
#  '232 - Højbjerg' 'Newry' '278 - Kolding, Agtrupvej'
#  'Birmingham Arcadian Centre' 'Canterbury Wincheap'
#  '239 - Århus C., Dalgas Avenue' 'Exeter Bishops Court'
#  '198 - Svendborg, Jernbanegade' 'London Greenwich Movement'
#  'Basel St. Johann' '176 - Søborg, Telefonvej' 'Jona'
#  '122 - Husum, Frederikssundsvej' '235 - Århus N., Vejlby Ringvej'
#  'Winterthur Grütze' '229 - Kastrup, Vestamagercentret'
#  '605 - Kbh. K., Købmagergade' '217 - Vanløse, Skalbakken'
#  '206 - Brønderslev' 'London Wall' '105 - Kongensgade, Esbjerg'
#  '625 - Brøndbyvester, Søndre Ringvej' '172 - Kbh. Ø., Strandvejen'
#  'East Grinstead' '126 - Vesterbro, Aalborg'
#  '222 - Helsingør, Søndre Strandvej' '269 - Gl. Hobrovej, Randers'
#  '289 - Trøjborg' '157 - Hundige, Waves' '251 - Busgaden, Århus'
#  '166 - Måløv, Stationsvej' '253 - Varde, Hjertingvej' '618 - Herlev, BIG'
#  '607 - Thors Bakke, Randers' '152 - Århus C., Scandinavian'
#  '130 - Sønderborg, Centerpassagen' '280 - Bagsværd, Vadstrupvej'
#  '101 - Kbh. V., Gasværksvej' '116 - Allerød, Banetorvet'
#  '178 - Odense SV., Bondovej' '216 - Århus C., Nørreport\xa0'
#  '254 - Esbjerg, Gl. Vardevej' '149 - Brøndby, Nygårds Plads'
#  '173 - Gugvej, Aalborg' '252 - Ishøj Bycenter' '204 - Hjørring'
#  'Tonbridge' '168 - Herning, Viborgvej' '187 - Næstved, Dania'
#  '128 - Århus V., Viborgvej' '142 - Fredensborg, Tinghusvej'
#  '205 - Skanderborg, Adelgade' '135 - Nykøbing F., Vestensborg Allé'
#  '266 - Skive' 'Edinburgh Waterfront' '237 - Slangerup, Idrætsvej'
#  '175 - Næstved, Grønvej' '136 - Greve, Håndværkerbyen'
#  '268 - Odense, Sankt Hans Gade' '245 - Kbh. N., Tagensvej'
#  '182 - Frederiksværk, Bagerstræde'] Unique Trust Pilot Locations
#  ['Solihull Sears Retail Park' 'Aylesbury' 'Sutton Times Square'
#  'London Finchley' 'Crayford' 'Stirling' nan 'Barnstaple'
#  'Catford Rushey Green' 'London Aldgate' 'Hemel Hempstead'
#  'Leeds City Centre South' 'London Bermondsey' 'West Bromwich'
#  'Broadstairs' 'Kirkcaldy' 'Durham Arnison' 'London Muswell Hill'
#  'Chester' 'Camberley' 'Derby' 'London Croydon' 'Edinburgh West'
#  'Llantrisant' 'Wolverhampton South' 'Nottingham Beeston'
#  'London Swiss Cottage' 'Widnes' 'Manchester First Street' 'Dunfermline'
#  'Bristol Harbourside' 'London Wembley' 'Sunderland'
#  'Birmingham Snow Hill Plaza' 'Stoke-on-Trent East' 'Dumfries' 345
#  'London Seven Sisters' 'Norwich Aylsham Road' 'Lisburn Laganbank'
#  'Caerphilly' 'South Ruislip' 'East Grinstead' 'Mansfield' 'Hull Anlaby'
#  'Colchester Retail Park' 'Cambridge Leisure Park' 'Brighton Central'
#  'London Hayes' 'Portsmouth Commercial Road' 'Watford Waterfields'
#  'Oxford Central' 'Wrexham' 'London Sydenham' 'Ipswich Ravenswood'
#  'Rochdale' 'Cirencester Retail Park' 'Southampton Bitterne'
#  'London Ilford' 'Norwich Castle Mall' 'London Kingston'
#  'Ipswich Buttermarket' 'Walton-on-Thames' 'Cardiff Bay' 'New Barnet'
#  'Aberdeen Shiprow' 'Merthyr Tydfil' 'Bristol Abbey Wood Retail Park'
#  'Yate' 'Chelmsford Meadows' 'London Waterloo' 'London Hoxton'
#  'Manchester Urban Exchange' 'Aberdeen Wellington Circle'
#  'London Marylebone' 'London Stratford' 'Leicester St Georges Way'
#  'Nottingham Colwick' 'Sevenoaks' 'York' 'Newcastle St James'
#  'Great Yarmouth' 'Eastbourne' 'Manchester Cheetham Hill'
#  'London Greenwich Movement' 'London Hammersmith Palais' 'Bicester'
#  'Birmingham Beaufort Park' 'Chippenham' 'Plymouth Marsh Mills'
#  'Burgess Hill' 'London Fulham' 'Wolverhampton Bentley Bridge' 'Harrogate'
#  'Cardiff Gate' 'Paisley' 'Ashford Warren Retail Park' 'Motherwell'
#  'Purley' 'Bournemouth the Triangle' 'Yeovil Houndstone Retail Park'
#  'Birmingham City Centre' 'Bromborough' 'Blyth'
#  'Torquay Bridge Retail Park' 'Taunton Riverside' 'Woking'
#  'Glasgow Robroyston' 'Plymouth Alexandra Road' 'Folkestone'
#  'Bournemouth Mallard Road' 'Harlow' 'Stockport South'
#  'Wirral Bidston Moss' 'Cardiff Western Avenue' 'Sutton Coldfield'
#  'Linlithgow' 'Peterborough Serpentine Green' 'Coventry Skydome'
#  'Bangor Wales' 'London Acton' 'Macclesfield Silk Road'
#  'Manchester Stretford' 'London Kentish Town' 'London Beckton' 'Byfleet'
#  398 'Exeter Fore Street' 'Edinburgh Ocean Terminal' 'Oldham'
#  'Bradford Thornbury' 'Evesham' 'Bedford Heights' 'Consett'
#  'Glasgow Charing Cross' 'Bradford Idle'
#  'Peterborough Brotherhood Retail Park' 'Gloucester Retail Park'
#  'Stafford' 'Walsall Crown Wharf' 'Leeds City Centre North' 'Lincoln'
#  'Birmingham Arcadian Centre' 'London Orpington Central'
#  'Edinburgh Exchange Crescent' 'Northwich' 'London Charlton' 'Poole'
#  'Edinburgh Fort Kinnaird' 'Wisbech' 'London Wandsworth' 'Preston'
#  'Glossop' 'London Borough' 'Crewe Grand Junction' 'Runcorn'
#  'Leeds Hunslet' 'Newport Gwent' 'Sheffield Millhouses'
#  'London Finsbury Park' 'Dagenham' 'Dudley Tipton' 'Edinburgh Quartermile'
#  'Birmingham West' 'Reading Calcot' 'London Enfield' 'Glasgow Silverburn'
#  'Buckingham' 'London Bayswater' 'Derry Londonderry' 'Southampton Shirley'
#  'Belfast Adelaide Street' 'Romford' 'Stowmarket' 'Brighton London Road'
#  'Gateshead' 'Bangor Northern Ireland' 'Ashton-Under-Lyne'
#  'Nottingham West Bridgford' 'Boston' 'West Thurrock' 'London East Sheen'
#  'Manchester Moston' 'Livingston' 'London Park Royal'
#  'Luton and Dunstable' 'Tunbridge Wells' 'London Angel' 'Wakefield'
#  "Belfast St Anne's Square" 'Leeds Kirkstall Bridge' 'Basildon'
#  'Weston-super-Mare' 'Newbury' 'Norwich Riverside' 'Alloa' 'Telford'
#  'London Whitechapel' 'Leamington Spa' 'Portsmouth North Harbour'
#  'Stockport North' 'Doncaster' 'Canterbury Riverside' 'Leeds Thorpe Park'
#  'Newcastle Longbenton' 'Cambridge Grafton Centre' 'Chatham'
#  'Blackburn The Mall' 'Northampton Weston Favell' 'Lichfield'
#  'Maidstone The Mall' 'Southampton Central' 'Sheffield Meadowhall'
#  'Salisbury' 'Sheffield City Centre South' 'Derby Kingsway'
#  'London Twickenham' 'Nuneaton' 'Walsall' 'Falkirk' 'Bristol Brislington'
#  'Corby' 'Bristol Eastgate' 'Reading Basingstoke Road' 'Port Talbot'
#  'Leicester Walnut Street' 'London St Pauls' 'Salford' 'Epsom' 'Dundee'
#  'Elgin' 'Swindon Mannington Retail Park' 'Tyldesley' 'Manchester Debdale'
#  'Inverness Inshes Retail Park' 'Ballymena' 'St Albans' 'London Lewisham'
#  'Belfast Boucher Road' 'Hatfield' 'Birmingham Longbridge'
#  'Glasgow Clydebank' 'London Southgate' 'Reading Caversham Road'
#  'Exeter Bishops Court' 'London Colindale'
#  'Aldershot Westgate Retail Park' 'London Tottenham Court Road'
#  'London Kidbrooke Village' 'Heanor' 'Swindon Stratton'
#  'Liverpool Edge Lane' 'Aberdeen Rubislaw' 'Leeds Regent Street' 'Staines'
#  'Canterbury Sturry Road' 'London Piccadilly' 'London Clapham'
#  'Manchester Market Street' 'Bridgwater' 'St Ives' 'Newry'
#  'Hednesford Cannock' 'Haverhill' 'Witney' 'Maidenhead' 'Knarebsorough'
#  'Bletchley' 'Oxford Templars Shopping Park' 'Aintree' 'Gravesend'
#  'Leeds Bramley' 'Bath Victoria Park' 'Brierley Hill' 'Rushden'
#  'Coventry Bishop Street' 'Warrington North' 'Portishead'
#  'London Camberwell New Road' 'London Farringdon' 'Liverpool Brunswick'
#  'Southport' 'London Wall' 'Banbury Cross Retail Park'
#  'Nottingham Castle Marina' 'Bury' 'Dover' 'Camden' 'London Bromley'
#  'Denton' 'Maldon Blackwater Retail Park' 'Halifax'
#  'Newcastle Eldon Garden' 'Andover' 'London Leytonstone'
#  'Cheshunt Brookfield Shopping Park' 'Glasgow Bath Street' 'Palmers Green'
#  'Stoke on Trent North' 'London Greenwich' 'Aberdeen Kittybrewster'
#  'Waterlooville' 'Burnham' 'London Crouch End' 'London Limehouse'
#  'London North Finchley' 'Manchester Spinningfields' 'Borehamwood'
#  'Manchester Bury New Road' 'Stratford upon Avon' 'London Canary Wharf'
#  'Liverpool Central' 'Galashiels' 'Trowbridge' 'Glasgow Giffnock'
#  'Worcester' 'Uttoxeter' 'Saffron Walden' 'Altrincham' 'Bath Spring Wharf'
#  'Glasgow Hope Street' 'London Edgware' 'Edinburgh Craigleith, ID 317'
#  'Southend Fossetts Park' 'Didcot' 'Milton Keynes Kingston Centre'
#  'Hereford' 'Glasgow Shawlands' 'Bracknell' 'London East India Dock'
#  'London Holloway Road' 'Warrington Central'
#  'Coventry Warwickshire Shopping Park' 'Colne' 'Stevenage'
#  'London Holborn' 'Manchester Eccles' 'Milton Keynes Winterhill'
#  'Glasgow Milngavie' 'Redditch' 'Northolt' 'London Oval'
#  'London Streatham' 'Loughborough' 'London Lambeth'
#  'London Great Portland Street' 'Lincoln Carlton Centre' 'Coleraine'
#  'Nottingham Basford' 'Rayleigh' 'Sheffield Crystal Peaks'
#  'Redditch Ringway' 'Manchester Exchange Quay' 'Fareham' 'East Kilbride'
#  'Ormskirk' 'Grantham Discovery Retail Park' 'London Putney'
#  'Northampton Central' 'Billericay' 'Gloucester Quedgeley' 'Hitchin'
#  'London Tower Hill' 'Newtownabbey' 'London Shoreditch'
#  'Cannock Orbital Retail Park' 'Bromsgrove Retail Park' 'Grimsby'
#  'Northallerton' 'London Bow Wharf' 'Birmingham Maypole' 'London Bank'
#  'Bristol Union Gate' 'London Camberwell Southampton Way'
#  'Cardiff Central' 'Tonbridge' 'Edinburgh Waterfront']

# %%
unique_locations_trust = np.array(unique_locations_trust,dtype=str)
unique_locations_google = np.array(unique_locations_google,dtype=str)

# %%
lower_trust = np.char.lower(unique_locations_trust)
lower_google = np.char.lower(unique_locations_google)

# %%
common_locations = np.intersect1d(lower_google,lower_trust, assume_unique= True, return_indices=False)
 
print("Number of Common Locations:\n",len(common_locations))
# Out:
# Number of Common Locations:
#  312

# %%
from fuzzywuzzy import fuzz

# %%
def fuzzy_match_locations(list1, list2, threshold=90):
    """Returns a list of locations from list1 that have a fuzzy match in list2."""
    
    matched_locations = set()  # Using a set to prevent duplicates
    
    list1_lower = [str(loc).lower() for loc in list1]  # Convert once instead of every iteration
    list2_lower = [str(loc).lower() for loc in list2]

    for loc1, loc1_original in zip(list1_lower, list1):  # Keep original names
        for loc2 in list2_lower:
            if fuzz.ratio(loc1, loc2) >= threshold:
                matched_locations.add(loc1_original)  # Add original name
                break  # No need to keep checking once a match is found

    return list(matched_locations)

# Get the common locations
common_locations_2 = fuzzy_match_locations(unique_locations_google, unique_locations_trust)

common_locations_2 = [str(location) for location in common_locations_2]
common_locations_2 = [loc.lower() for loc in common_locations_2]

print("Number of matched locations:", len(common_locations_2))
print("Common Locations (with possible spelling errors):", common_locations_2)
# Out:
# Number of matched locations: 316
# Common Locations (with possible spelling errors): ['milton keynes winterhill', 'bath spring wharf', 'bicester', 'birmingham beaufort park', 'coventry skydome', 'sutton coldfield', 'chatham', 'london hoxton', 'belfast boucher road', 'london beckton', 'telford', 'wolverhampton bentley bridge', 'london swiss cottage', 'southampton central', 'lichfield', 'london putney', 'south ruislip', 'northwich', 'london angel', 'southampton shirley', 'london east india dock', 'derry londonderry', 'manchester urban exchange', 'northolt', 'nottingham beeston', 'london sydenham', 'northampton central', 'portsmouth north harbour', 'hereford', 'stockport north', 'glossop', 'tyldesley', 'milton keynes kingston centre', 'london crouch end', 'nuneaton', 'consett', 'manchester debdale', 'newbury', 'sutton times square', 'london borough', 'birmingham arcadian centre', 'london limehouse', 'redditch ringway', 'sevenoaks', 'purley', 'burnham', 'liverpool brunswick', 'colchester retail park', 'woking', 'wrexham', 'london lewisham', 'bath victoria park', 'tonbridge', 'wakefield', 'london kidbrooke village', 'uttoxeter', 'leeds city centre north', 'leeds kirkstall bridge', 'falkirk', 'london acton', 'aylesbury', 'eastbourne', 'cambridge leisure park', 'tunbridge wells', 'london enfield', 'sheffield meadowhall', 'chester', 'london kingston', 'birmingham city centre', 'cardiff gate', 'new barnet', 'london fulham', 'blackburn the mall', 'corby', 'worcester', 'norwich castle mall', 'york', 'stafford', 'manchester exchange quay', 'galashiels', 'glasgow clydebank', 'sunderland', 'southend fossetts park', 'poole', 'lisburn laganbank', 'sheffield millhouses', 'glasgow bath street', 'edinburgh waterfront', 'cardiff central', 'coleraine', 'brighton london road', 'cardiff western avenue', 'knaresborough', 'norwich riverside', 'andover', 'london aldgate', 'oldham', 'aberdeen shiprow', 'london lambeth', 'nottingham castle marina', 'hednesford cannock', 'blyth', 'bangor northern ireland', 'east kilbride', 'manchester cheetham hill', 'london waterloo', 'london marylebone', 'merthyr tydfil', 'epsom', 'west bromwich', 'london hayes', 'gloucester quedgeley', 'grimsby', 'maidstone - the mall', 'bridgwater', 'aintree', 'buckingham', 'plymouth alexandra road', 'manchester market street', 'liverpool central', 'gateshead', 'preston', 'brierley hill', 'london kentish town', 'swindon mannington retail park', 'altrincham', 'manchester spinningfields', 'romford', 'mansfield', 'rochdale', 'newport gwent', 'ormskirk', 'portsmouth commercial road', 'birmingham longbridge', 'yate', 'caerphilly', 'derby', 'bournemouth - mallard road', 'leeds regent street', 'warrington central', 'barnstaple', 'folkestone', 'london whitechapel', 'london seven sisters', 'watford waterfields', 'london colindale', 'dudley tipton', 'bristol brislington', 'basildon', 'manchester moston', 'portishead', 'london bromley', 'hemel hempstead', 'maidenhead', 'reading calcot', 'coventry bishop street', 'nottingham basford', 'bury', 'london greenwich movement', 'southport', 'london clapham', 'leeds city centre south', 'lincoln carlton centre', 'warrington north', 'london st pauls', 'harrogate', 'nottingham colwick', 'leicester st georges way', 'london bank', 'exeter fore street', 'motherwell', 'manchester stretford', 'edinburgh fort kinnaird', 'glasgow giffnock', 'birmingham west', 'london - twickenham', 'salisbury', 'northallerton', 'norwich aylsham road', 'southampton bitterne', 'london wembley', 'glasgow shawlands', 'loughborough', 'paisley', 'west thurrock', 'sheffield crystal peaks', 'london croydon', 'london bayswater', 'leamington spa', 'nottingham west bridgford', 'denton', 'london oval', 'bradford thornbury', 'london great portland street', 'bletchley', 'exeter bishops court', 'colne', 'dundee', 'kirkcaldy', 'london piccadilly', 'london tower hill', 'oxford templars shopping park', 'bromborough', 'london orpington central', 'london bermondsey', 'london tottenham court road', 'glasgow hope street', 'cannock orbit ...

# %% [markdown]
# ## Pre-Processing the data
# #### Change to Lower Case,Remove Stopwords using NLTK,Remove Numbers

# %%
def clean_text(text):
    
    text_1 = re.sub(r'<.*?>','',text)
    
    text_2 = re.sub(r'[\d' + re.escape(string.punctuation) + ']+', '', text_1)
    
    cleaned_text = re.sub(r'\s+', ' ', text_2).strip()
    
    return cleaned_text

# %%
#Check 1.2.3 for NLTK pre-processing

stop_words = set(stopwords.words('english'))

def pre_process(text):
    
    # Tokenise and transform to lower
    
    tokens = word_tokenize(text.lower())
    
    # Remove Stopwords
    
    filtered_tokens = [token for token in tokens if token not in stop_words]
    
    lemmatizer = WordNetLemmatizer()
    
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]
    
    final_text = ' '.join(lemmatized_tokens)
    
    
    return final_text

# %%
google_clean = google_text['Comment'].apply(clean_text)
google_pro = google_clean.apply(pre_process)

trust_clean = trust_text['Review Content'].apply(clean_text)
trust_pro = trust_clean.apply(pre_process)

# %%
root_dir = os.path.dirname(os.getcwd())

joblib_dir = os.path.join(root_dir, 'joblib_files')

if not os.path.exists(joblib_dir):
    os.makedirs(joblib_dir)
    
save_joblib(google_pro, os.path.join(joblib_dir, 'google_pro.joblib'))
# Out:
# Save to /home/sanyasetia/topic-project/joblib_files/google_pro.joblib

# %%
if not os.path.exists(joblib_dir):
    os.makedirs(joblib_dir)
    
save_joblib(trust_pro, os.path.join(joblib_dir, 'trust_pro.joblib'))
# Out:
# Save to /home/sanyasetia/topic-project/joblib_files/trust_pro.joblib
